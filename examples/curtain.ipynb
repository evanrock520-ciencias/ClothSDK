# %%
from tissu import Simulation

# %%
sim = Simulation(substeps=10, iterations=3, thickness=0.05)
curtain = sim.create_grid(
    name="curtain",
    rows=80,
    cols=80,
    spacing=0.05,
    material="silk"
)
# Out:
# [Tissu][INFO] Successfully added fabric: curtain

# %%
initial = -2.0
speed = 0.05
sim.add_sphere("ball", center=[initial, 0.0, 0.0], radius=1, friction=0.5)
# Out:
# [Tissu][INFO] Added sphere collider 'ball' at [-2.0, 0.0, 0.0]

# %%
@sim.on_range(0, 180)
def move_ball(sim):
    t = sim.frame / 180.0
    x = -0.8 + t * 1.6
    sim.move_collider("ball", [x, 0.0, 0.0])

# %% [markdown]
# # Previsualize

# %%
sim.view()

# %% [markdown]
# # Bake

# %%
sim.bake_alembic(
    filepath="../data/animations/bounce.abc",
    start_frame=0,
    end_frame=240,
    fps=60
)
# Out:
# [Tissu][INFO] Baking simulation to ../data/animations/bounce.abc...
# Baking Alembic: 100%|██████████| 240/240 [02:31<00:00,  1.58frames/s]
# True
# [Tissu][INFO] Bake completed successfully: ../data/animations/bounce.abc
